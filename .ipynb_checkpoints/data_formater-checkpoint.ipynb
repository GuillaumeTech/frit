# %% [markdown]
# #### lib imports

# %%
import pandas as pd
import random
from IPython.display import display, HTML

# %% [markdown]
# #### files imports
# Those are big files so we load them in a spearated cell

# %%
ricardo = pd.read_json('./data/ricardo.json', encoding="utf8")
marmitton = pd.read_json('./data/marmiton.json', encoding="utf8")

# %% [markdown]
# keep only the first 1000 elements so it easier to work with and every site bring the same proportion of data

# %%
ricardo_limited = ricardo.head(1000)
marmitton_limited = marmitton.head(1000)

# %%
ing = [*ricardo_limited.ingredients.sum(), *marmitton_limited.ingredients.sum()]


ing_splited = [i.split() for i in ing]
random.shuffle(ing_splited)
[i.append(" ") for i in ing_splited]
ing_splited
flat_list = [item for sublist in ing_splited for item in sublist]
display(flat_list)
# Out:
# ['675',
#  'g',
#  '(1',
#  '1/2',
#  'lb)',
#  'de',
#  'filet,',
#  'de',
#  'contre-filet',
#  'ou',
#  'de',
#  'surlonge',
#  'de',
#  'boeuf,',
#  'coupé',
#  'en',
#  '32',
#  'cubes',
#  'd’environ',
#  '4',
#  'cm',
#  '(1',
#  '1/2',
#  'po)',
#  ' ',
#  '1',
#  'cuillère',
#  'à',
#  'café',
#  'de',
#  'cannelle',
#  ' ',
#  '1',
#  'ml',
#  '(1/4',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'cannelle',
#  ' ',
#  '5',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'thé)',
#  "d'essence",
#  'de',
#  'vanille',
#  ' ',
#  'none',
#  'oignon',
#  ' ',
#  '25',
#  'cl',
#  'de',
#  'bouillon',
#  ' ',
#  '1',
#  'bulbe',
#  'd’ail',
#  'entier',
#  ' ',
#  'sel',
#  'et',
#  'poivre',
#  ' ',
#  '1',
#  'gousse',
#  'd’ail,',
#  'hachée',
#  'finement',
#  ' ',
#  '1',
#  'carotte',
#  ' ',
#  '540',
#  'ml',
#  '(19',
#  'oz)',
#  'de',
#  'haricots',
#  'noirs,',
#  'rincés',
#  'et',
#  'égouttés',
#  ' ',
#  '1',
#  'oeuf,',
#  'légèrement',
#  'battu',
#  'pour',
#  'badigeonner',
#  ' ',
#  '310',
#  'ml',
#  '(1',
#  '1/4',
#  'tasse)',
#  'de',
#  'farine',
#  ' ',
#  '60',
#  'g',
#  '(2',
#  'tasses)',
#  'de',
#  'feuilles',
#  'de',
#  'coriandre',
#  'fraîche',
#  ' ',
#  '1',
#  'pointe',
#  'de',
#  'couteau',
#  ' ',
#  'riz,',
#  'cuit',
#  'vapeur',
#  ' ',
#  '50',
#  'g',
#  'de',
#  'beurre',
#  ' ',
#  'none',
#  'poivre',
#  ' ',
#  '500',
#  'ml',
#  '(2',
#  'tasses)',
#  'de',
#  'pommes',
#  'de',
#  'terre',
#  'coupées',
#  'en',
#  'dés',
#  '(non',
#  'pelées',
#  'et',
#  'bien',
#  'nettoyées)',
#  ' ',
#  '15',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'beurre,',
#  'ramolli',
#  ' ',
#  '1',
#  'blanc',
#  'de',
#  'poireaux',
#  ' ',
#  '250',
#  'g',
#  'de',
#  'jambon',
#  ' ',
#  '15',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'sucre',
#  ' ',
#  '1',
#  'boîte',
#  'de',
#  '540',
#  'ml',
#  '(19',
#  'oz)',
#  'de',
#  'pois',
#  'chiches,',
#  'rincés',
#  'et',
#  'égouttés',
#  ' ',
#  '1',
#  'oignon',
#  ' ',
#  '1',
#  'carotte,',
#  'pelée',
#  'et',
#  'coupée',
#  'en',
#  'fine',
#  'julienne',
#  ' ',
#  '2',
#  'litres',
#  '(8',
#  'tasses)',
#  'd’épinards',
#  'tassés,',
#  'hachés',
#  ' ',
#  '1',
#  'gousse',
#  "d'ail",
#  ' ',
#  '150',
#  'g',
#  'de',
#  'carotte',
#  ' ',
#  'none',
#  'câpres',
#  ' ',
#  '2,5',
#  'ml',
#  '(1/2',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'moutarde',
#  'sèche',
#  ' ',
#  '3',
#  'échalotes',
#  'françaises,',
#  'hachées',
#  ' ',
#  '180',
#  'g',
#  'de',
#  'pâte',
#  ' ',
#  '250',
#  'ml',
#  '(1',
#  'tasse)',
#  'de',
#  'lait',
#  ' ',
#  'ou',
#  ' ',
#  '5',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'graines',
#  'de',
#  'sésame,',
#  'grillées',
#  'ou',
#  'non',
#  ' ',
#  '2',
#  'cuillères',
#  'à',
#  'soupe',
#  'de',
#  'farine',
#  ' ',
#  '10',
#  'cl',
#  'de',
#  'lait',
#  ' ',
#  'ou',
#  ' ',
#  '225',
#  'g',
#  '(1/2',
#  'lb)',
#  'de',
#  'haricots',
#  'verts,',
#  'parés',
#  ' ',
#  '2',
#  'poireaux',
#  ' ',
#  '15',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'sumac',
#  'moulu',
#  ' ',
#  'none',
#  'emmental',
#  ' ',
#  '50',
#  'g',
#  'de',
#  'fromage',
#  'râpé',
#  ' ',
#  '250',
#  'ml',
#  '(1',
#  'tasse)',
#  'de',
#  'bouillon',
#  'de',
#  'poulet,',
#  'environ',
#  ' ',
#  '1',
#  'cuillère',
#  'à',
#  'soupe',
#  'de',
#  'concentré',
#  'de',
#  'tomates',
#  ' ',
#  '25',
#  'cl',
#  'de',
#  'crème',
#  'liquide',
#  ' ',
#  '2',
#  'gousses',
#  'd’ail,',
#  'hachées',
#  ' ',
#  '2',
#  'cuillères',
#  'à',
#  'soupe',
#  'de',
#  'câpres',
#  ' ',
#  '50',
#  'g',
#  'de',
#  'noix',
#  'de',
#  'coco',
#  'rapée',
#  ' ',
#  '1',
#  'oignon,',
#  'coupé',
#  'en',
#  'fins',
#  'quartiers',
#  ' ',
#  'none',
#  'tomate',
#  ' ',
#  'none',
#  'sel',
#  ' ',
#  '4',
#  'tranches',
#  'de',
#  'pain',
#  'grillées,',
#  'sans',
#  'les',
#  'croûtes',
#  ' ',
#  '200',
#  'g',
#  'de',
#  'chapelure',
#  ' ',
#  'none',
#  'amandes',
#  ' ',
#  '2,5',
#  'ml',
#  '(1/2',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'sel',
#  ' ',
#  '100',
#  'confiture',
#  ' ',
#  '750',
#  'ml',
#  '(3',
#  'tasses)',
#  'de',
#  'chou-fleur',
#  'coupé',
#  'en',
#  'petits',
#  'bouquets',
#  ' ',
#  '1',
#  'poivron',
#  'rouge,',
#  'épépiné',
#  'et',
#  'coupé',
#  'en',
#  'dés',
#  ' ',
#  'quartiers',
#  'de',
#  'lime',
#  'ou',
#  'de',
#  'citron',
#  '(facultatif)',
#  ' ',
#  '500',
#  'g',
#  "d'échine",
#  'de',
#  'porc',
#  ' ',
#  '30',
#  'ml',
#  '(2',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'poudre',
#  'd’amandes',
#  ' ',
#  '3',
#  'jaunes',
#  "d'oeuf",
#  ' ',
#  '1',
#  'oignon,',
#  'haché',
#  'finement',
#  ' ',
#  '2',
#  'cuillères',
#  'à',
#  'soupe',
#  'de',
#  'miel',
#  ' ',
#  '60',
#  'ml',
#  '(¼',
#  'tasse)',
#  'de',
#  'crème',
#  'sure',
#  '(facultatif)',
#  ' ',
#  '1',
#  'oignon,',
#  'émincé',
#  ' ',
#  '250',
#  'ml',
#  '(1',
#  'tasse)',
#  'de',
#  'vin',
#  'blanc',
#  ' ',
#  'none',
#  'coquille',
#  'saint-jacques',
#  ' ',
#  '5',
#  'cl',
#  'de',
#  'vinaigre',
#  'balsamique',
#  ' ',
#  'none',
#  'jambon',
#  ' ',
#  'beurre',
#  'ramolli,',
#  'pour',
#  'la',
#  'cuisson',
#  ' ',
#  '250',
#  'g',
#  'de',
#  'fraises',
#  ' ',
#  '2.5',
#  'g',
#  'de',
#  'levure',
#  ' ',
#  'sel',
#  'et',
#  'poivre',
#  ' ',
#  '30',
#  'ml',
#  '(2',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'jus',
#  'de',
#  'citron',
#  ' ',
#  '1',
#  'oignon',
#  'moyen,',
#  'haché',
#  ' ',
#  '30',
#  'ml',
#  '(2',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'persil',
#  'plat',
#  'ciselé',
#  ' ',
#  '2',
#  'boîtes',
#  'de',
#  '540',
#  'ml',
#  '(19',
#  'oz)',
#  'de',
#  'haricots',
#  'blancs,',
#  'rincés',
#  'et',
#  'égouttés',
#  ' ',
#  '454',
#  'g',
#  '(1',
#  'lb)',
#  'de',
#  'veau',
#  'haché',
#  ' ',
#  '225',
#  'g',
#  '(1/2',
#  'livre)',
#  'de',
#  'brie',
#  'avec',
#  'ou',
#  'sans',
#  'croûte,',
#  'coupé',
#  'en',
#  'morceaux',
#  ' ',
#  '2',
#  'gousses',
#  'd’ail,',
#  'hachées',
#  ' ',
#  '100',
#  'g',
#  'de',
#  'lardons',
#  ' ',
#  '35',
#  'g',
#  '(1/4',
#  'tasse)',
#  'de',
#  'fécule',
#  'de',
#  'maïs',
#  ' ',
#  '5',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'thé)',
#  "d'huile",
#  'de',
#  'sésame',
#  'grillé',
#  ' ',
#  '15',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'moutarde',
#  'de',
#  'dijon',
#  ' ',
#  '125',
#  'g',
#  'de',
#  'sucre',
#  ' ',
#  '8',
#  'biscuits',
#  'soda,',
#  'concassés',
#  ' ',
#  '100',
#  'g',
#  'de',
#  'noix',
#  ' ',
#  '6',
#  'filets',
#  'de',
#  'limande',
#  ' ',
#  '30',
#  'ml',
#  '(2',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'jus',
#  'de',
#  'citron',
#  ' ',
#  '15',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'tapioca',
#  'à',
#  'cuisson',
#  'rapide',
#  ' ',
#  '2',
#  'cuillères',
#  'à',
#  'soupe',
#  'de',
#  'persil',
#  ' ',
#  'none',
#  'moutarde',
#  ' ',
#  '1',
#  'ail',
#  ' ',
#  '5',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'sauce',
#  'harissa',
#  ' ',
#  'piment',
#  'de',
#  'cayenne,',
#  'au',
#  'goût',
#  ' ',
#  '500',
#  'ml',
#  '(2',
#  'tasses)',
#  'de',
#  'riz',
#  'arborio',
#  ' ',
#  'none',
#  'artichaut',
#  ' ',
#  '600',
#  'ml',
#  'de',
#  'lait',
#  ' ',
#  'huile',
#  "d'olive",
#  'supplémentaire',
#  ' ',
#  '150',
#  'g',
#  '(1',
#  'tasse)',
#  'de',
#  'farine',
#  'tout',
#  'usage',
#  'non',
#  'blanchie',
#  ' ',
#  'none',
#  'fromage',
#  ' ',
#  '5',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'cinq-épices',
#  ' ',
#  '2',
#  'oignons',
#  ' ',
#  '2',
#  'filets',
#  'mignons',
#  ' ',
#  '30',
#  'ml',
#  '(2',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'farine',
#  'de',
#  'maïs',
#  ' ',
#  '25',
#  'g',
#  '(1/2',
#  'tasse)',
#  'de',
#  'coriandre',
#  'ciselée',
#  ' ',
#  '125',
#  'ml',
#  '(1/2',
#  'tasse)',
#  'de',
#  'whisky',
#  ' ',
#  '2',
#  'poires',
#  ' ',
#  'le',
#  'zeste',
#  'râpé',
#  'd’une',
#  'orange',
#  ' ',
#  '5',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'cumin',
#  'moulu',
#  ' ',
#  '250',
#  'g',
#  'de',
#  'fruit',
#  'confit',
#  ' ',
#  '1',
#  'kg',
#  'de',
#  'boeuf',
#  ' ',
#  '1,4',
#  'kg',
#  '(3',
#  'lb)',
#  'de',
#  'flanc',
#  'de',
#  'veau',
#  'désossé,',
#  'en',
#  'un',
#  'morceau',
#  '(aussi',
#  'appelé',
#  'poitrine)',
#  ' ',
#  'none',
#  'gruyère',
#  'râpé',
#  ' ',
#  '1',
#  'poireau',
#  ' ',
#  'le',
#  'jus',
#  'et',
#  'le',
#  'zeste',
#  'de',
#  '1/2',
#  'lime',
#  ' ',
#  '1',
#  'filet',
#  'de',
#  'crème',
#  ' ',
#  'none',
#  'sel',
#  ' ',
#  '1',
#  'poulet',
#  ' ',
#  '5',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'grains',
#  'de',
#  'poivre',
#  'noir,',
#  'concassés',
#  ' ',
#  '12',
#  'carrés',
#  'de',
#  'chocolat',
#  'blanc',
#  ' ',
#  '15',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'jus',
#  'de',
#  'lime',
#  ' ',
#  'sel',
#  'et',
#  'poivre',
#  ' ',
#  '1',
#  'l',
#  'de',
#  'vin',
#  'blanc',
#  'sec',
#  ' ',
#  '1',
#  'sachet',
#  'de',
#  'chou',
#  'blanc',
#  ' ',
#  '1',
#  'cuillère',
#  'à',
#  'soupe',
#  'de',
#  'curcuma',
#  ' ',
#  'none',
#  'gruyère',
#  'râpé',
#  ' ',
#  '1',
#  'pincée',
#  'de',
#  'muscade',
#  ' ',
#  'none',
#  'poivre',
#  ' ',
#  '1',
#  'ml',
#  '(1/4',
#  'c.',
#  'à',
#  'thé)',
#  'de',
#  'sel',
#  ' ',
#  'none',
#  'thym',
#  ' ',
#  'sel',
#  'et',
#  'poivre',
#  ' ',
#  '60',
#  'ml',
#  '(¼',
#  'tasse)',
#  'de',
#  'raisins',
#  'de',
#  'corinthe',
#  ' ',
#  '1',
#  'pincée',
#  'de',
#  'poivre',
#  ' ',
#  '2',
#  'carottes',
#  'blanchies,',
#  'coupées',
#  'en',
#  'deux',
#  'sur',
#  'la',
#  'longueur,',
#  'puis',
#  'tranchées',
#  ' ',
#  '1/2',
#  'verre',
#  "d'eau",
#  ' ',
#  '4',
#  'pommes',
#  'cortland,',
#  'pelées,',
#  'épépinées',
#  'et',
#  'tranchées',
#  ' ',
#  '200',
#  'g',
#  'de',
#  'noix',
#  ' ',
#  '10',
#  'cl',
#  "d'eau",
#  ' ',
#  '15',
#  'ml',
#  '(1',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'pâte',
#  'de',
#  'tomates',
#  ' ',
#  '45',
#  'ml',
#  '(3',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'vinaigre',
#  'de',
#  'vin',
#  'blanc',
#  ' ',
#  '30',
#  'ml',
#  '(2',
#  'c.',
#  'à',
#  'soupe)',
#  'de',
#  'fromage',
#  'mozzarella',
#  'râpé',
#  ' ',
#  '4',
#  ...]
